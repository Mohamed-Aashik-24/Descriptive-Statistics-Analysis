# %% [markdown]
# #**DATA SCIENCE AND VISUALIZATION - 24ADI204**
# ### World Happiness 2017 Dataset Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt

print("Name: Mohamed Aashik S \nRoll No: 24BAD072\n")
# Out:
# Name: Mohamed Aashik S
# Roll No: 24BAD072

# %%
df = pd.read_csv('/content/happiness_2017.csv')
df.head()
# Out:
#        Country          Region  Rank  HappinessScore  Life Ladder  \
# 0       Norway  Western Europe   1.0           7.537     7.578745
# 1      Denmark  Western Europe   2.0           7.522     7.593702
# 2      Iceland  Western Europe   3.0           7.504     7.476214
# 3  Switzerland  Western Europe   4.0           7.494     7.473593
# 4      Finland  Western Europe   5.0           7.469     7.788252
#
#    Log GDP per capita  Social support  Healthy life expectancy at birth  \
# 0           11.081789        0.950128                         71.086586
# 1           10.748989        0.952100                         71.662498
# 2           10.760409        0.966753                         72.755981
# 3           10.955548        0.949661                         73.173759
# 4           10.612338        0.963826                         71.696960
#
#    Freedom to make life choices  Generosity  Perceptions of corruption  \
# ...

# %%
# Descriptive Statistics
df.describe()
# Out:
#            Rank  HappinessScore  Life Ladder  Log GDP per capita  \
# count  140.0000      142.000000   140.000000          133.000000
# mean    70.5000        5.368702     5.491702            9.345615
# std     40.5586        1.159151     1.122178            1.184935
# min      1.0000        1.109750     2.661718            6.625341
# 25%     35.7500        4.537500     4.636694            8.545789
# 50%     70.5000        5.302000     5.586507            9.547693
# 75%    105.2500        6.152250     6.278276           10.313942
# max    140.0000        7.537000     7.788252           11.465231
#
#        Social support  Healthy life expectancy at birth  \
# count      139.000000                        140.000000
# mean         0.806711                         63.440981
# std          0.121117                          7.595597
# min          0.319589                         44.386528
# 25%          0.736748                         58.005130
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145 entries, 0 to 144
# Data columns (total 14 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Country                            140 non-null    object
#  1   Region                             140 non-null    object
#  2   Rank                               140 non-null    float64
#  3   HappinessScore                     142 non-null    float64
#  4   Life Ladder                        140 non-null    float64
#  5   Log GDP per capita                 133 non-null    float64
#  6   Social support                     139 non-null    float64
#  7   Healthy life expectancy at birth   140 non-null    float64
#  8   Freedom to make life choices       139 non-null    float64
#  9   Generosity                         132 non-null    float64
#  10  Perceptions of corruption          128 non-null    float64
# ...

# %% [markdown]
# ###1) Histogram: Distribution of Happiness Score

# %%
# Histogram for Happiness Score
plt.figure(figsize=(6,4))
plt.hist(df['HappinessScore'], bins=20)
plt.xlabel('Happiness Score')
plt.ylabel('Frequency')
plt.title('Distribution of Happiness Score')
plt.show()

# %% [markdown]
# ###2) Boxplot: Happiness Score

# %%
# Boxplot
plt.figure(figsize=(6,4))
plt.boxplot(df['HappinessScore'].dropna())
plt.ylabel('Happiness Score')
plt.title('Boxplot of Happiness Score')
plt.show()

# %% [markdown]
# ### Statistical Summary for Happiness Score (Histogram & Boxplot):
# *   **Count**: 142
# *   **Mean**: 5.37
# *   **Min**: 1.11, **Max**: 7.54

# %% [markdown]
# ###3) Scatter Plot: GDP vs. Happiness Score

# %%
# Scatter Plot: GDP vs Happiness Score
plt.figure(figsize=(6,4))
plt.scatter(df['Log GDP per capita'], df['HappinessScore'])
plt.xlabel('GDP per Capita')
plt.ylabel('Happiness Score')
plt.title('GDP vs Happiness Score')
plt.show()

# %% [markdown]
# ### Statistical Summary for GDP vs. Happiness Score (Scatter Plot):
# *   **HappinessScore**: Mean ~5.37, Range 1.11-7.54
# *   **Log GDP per capita**: Count 133, Mean ~9.35, Range 6.63-11.47

# %% [markdown]
# ###4) Bar Chart: Top 10 Happiest Countries

# %%
# Top 10 Happiest Countries
top10 = df.sort_values('HappinessScore', ascending=False).head(10)
plt.figure(figsize=(8,4))
plt.bar(top10['Country'], top10['HappinessScore'])
plt.xticks(rotation=45, ha='right')
plt.xlabel('Country')
plt.ylabel('Happiness Score')
plt.title('Top 10 Happiest Countries')
plt.show()

# %% [markdown]
# ### Statistical Summary for Top 10 Happiest Countries (Bar Chart):
# *   **Top 10 HappinessScore**: Count 10, Mean ~7.40, Range 7.21-7.54 (very narrow spread)

# %% [markdown]
# ###5) Correlation Matrix Plot

# %%
# Correlation Matrix Plot
corr = df.corr(numeric_only=True)
plt.figure(figsize=(8,6))
plt.imshow(corr)
plt.colorbar()
plt.xticks(range(len(corr.columns)), corr.columns, rotation=90)
plt.yticks(range(len(corr.columns)), corr.columns)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ### Statistical Summary for Correlation Matrix:
# *   **Correlation Coefficients**: Values between -1 and +1, indicating strength and direction of linear relationships between all numerical variables.

# %% [markdown]
# ###6) Line Plot: Happiness Score by Rank

# %%
plt.figure(figsize=(10,6))
plt.plot(df['Rank'], df['HappinessScore'])
plt.xlabel('Rank')
plt.ylabel('Happiness Score')
plt.title('Happiness Score by Rank')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Statistical Summary for Happiness Score by Rank (Line Plot):
# *   **HappinessScore**: Mean ~5.37, Range 1.11-7.54
# *   **Rank**: Count 140, Mean ~70.5, Range 1-140 (ordered sequence)
